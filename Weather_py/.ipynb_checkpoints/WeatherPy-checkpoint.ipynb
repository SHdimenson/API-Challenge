# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['kodiak',
#  'te anau',
#  'hobart',
#  'umzimvubu',
#  'victoria',
#  'mataura',
#  'zyryanovsk',
#  'taolanaro',
#  'oranjestad',
#  'lipin bor',
#  'mount gambier',
#  'amderma',
#  'saskylakh',
#  'leningradskiy',
#  'oxford',
#  'utete',
#  'lebu',
#  'saleaula',
#  'mahebourg',
#  'taltal',
#  'hilo',
#  'auki',
#  'tuktoyaktuk',
#  'mayo',
#  'rikitea',
#  'gat',
#  'semarang',
#  'vaini',
#  'saint george',
#  'alice springs',
#  'bluff',
#  'chuy',
#  'kaya',
#  'attawapiskat',
#  'souillac',
#  'cuiluan',
#  'punta arenas',
#  'lujan',
#  'iqaluit',
#  'ushuaia',
#  'mar del plata',
#  'wahiawa',
#  'barrow',
#  'ribeira grande',
#  'port elizabeth',
#  'cape town',
#  'qaanaaq',
#  'saldanha',
#  'gravelbourg',
#  'padang',
#  'yellowknife',
#  'tiksi',
#  'guerrero negro',
#  'pacific grove',
#  'puerto del rosario',
#  'port alfred',
#  'muncar',
#  'ponta do sol',
#  'castro',
#  'skibbereen',
#  'laguna',
#  'yumen',
#  'pachino',
#  'nikolskoye',
#  'san pedro',
#  'yerbogachen',
#  'belushya guba',
#  'bassano',
#  'carnarvon',
#  'saint-pierre',
#  'rossland',
#  'barentsburg',
#  'airai',
#  'kapaa',
#  'dikson',
#  'chateauroux',
#  'yabelo',
#  'puerto ayora',
#  'arraial do cabo',
#  'natal',
#  'khatanga',
#  'atuona',
#  'bima',
#  'cidreira',
#  'sabang',
#  'east london',
#  'adrar',
#  'busselton',
#  'berlevag',
#  'bathsheba',
#  'albany',
#  'cassilandia',
#  'marsh harbour',
#  'nadadores',
#  'mount isa',
#  'coquimbo',
#  'klaksvik',
#  'grand river south east',
#  'chumikan',
#  'butaritari',
#  'norman wells',
#  'new norfolk',
#  'upernavik',
#  'xuddur',
#  'ulladulla',
#  'thompson',
#  'zhigansk',
#  'jamestown',
#  'faya',
#  'surt',
#  'illoqqortoormiut',
#  'seoul',
#  'cabo san lucas',
#  'khonuu',
#  'kangalassy',
#  'teya',
#  'shediac',
#  'ushtobe',
#  'sun valley',
#  'okhotsk',
#  'nanortalik',
#  'port hawkesbury',
#  'vaitupu',
#  'lafia',
#  'grindavik',
#  'mys shmidta',
#  'jiangyin',
#  'solnechnyy',
#  'avarua',
#  'pontianak',
#  'clyde river',
#  'ambon',
#  'ilulissat',
#  'general roca',
#  'epe',
#  'georgetown',
#  'havoysund',
#  'roebourne',
#  'palu',
#  'korla',
#  'fortuna',
#  'kamenskoye',
#  'varna',
#  'cockburn town',
#  'comodoro rivadavia',
#  'bredasdorp',
#  'the pas',
#  'kahului',
#  'chokurdakh',
#  'bethel',
#  'hamilton',
#  'guelavia',
#  'gara',
#  'port blair',
#  'hithadhoo',
#  'saint-paul',
#  'ludvika',
#  'mackay',
#  'tessalit',
#  'viransehir',
#  'nelson bay',
#  'dongobesh',
#  'deputatskiy',
#  'los llanos de aridane',
#  'morondava',
#  'halalo',
#  'yamada',
#  'kamaishi',
#  'peniche',
#  'hovd',
#  'sorvag',
#  'yelan',
#  'rairangpur',
#  'torbay',
#  'glace bay',
#  'aykhal',
#  'talas',
#  'faanui',
#  'yuxia',
#  'winchester',
#  'lastoursville',
#  'palm coast',
#  'miraflores',
#  'modasa',
#  'hermanus',
#  'zhaodong',
#  'paamiut',
#  'rengali',
#  'kavieng',
#  'bengkulu',
#  'shakawe',
#  'vila',
#  'maniitsoq',
#  'nenjiang',
#  'alexandria',
#  'ancud',
#  'barcelos',
#  'meyungs',
#  'cayenne',
#  'santa rosa',
#  'beringovskiy',
#  'tuatapere',
#  'batesville',
#  'richards bay',
#  'coihaique',
#  'narsaq',
#  'tasiilaq',
#  'constitucion',
#  'betania',
#  'bambous virieux',
#  'petrozavodsk',
#  'galesburg',
#  'rapar',
#  'mendi',
#  'rockland',
#  'naze',
#  'tabligbo',
#  'marzuq',
#  'leshukonskoye',
#  'phun phin',
#  'sentyabrskiy',
#  'cabatuan',
#  'longyearbyen',
#  'malokakhovka',
#  'flinders',
#  'kazalinsk',
#  'lufilufi',
#  'vangaindrano',
#  'muli',
#  'tual',
#  'horten',
#  'provideniya',
#  'roma',
#  'calabozo',
#  'nemuro',
#  'codrington',
#  'daru',
#  'achisay',
#  'kruisfontein',
#  'galesong',
#  'surskoye',
#  'praia da vitoria',
#  'umtata',
#  'santa fe',
#  'bastia',
#  'weinan',
#  'vardo',
#  'huntsville',
#  'inyonga',
#  'loandjili',
#  'sucre',
#  'sobolevo',
#  'waipawa',
#  'vila franca do campo',
#  'verkhoyansk',
#  'san lawrenz',
#  'surab',
#  'toda raisingh',
#  'tecoanapa',
#  'bandundu',
#  'labuhan',
#  'linqiong',
#  'mankono',
#  'lazaro cardenas',
#  'esperance',
#  'beloha',
#  'talaya',
#  'porto novo',
#  'qaqortoq',
#  'batemans bay',
#  'rio de janeiro',
#  'nizhneyansk',
#  'mentok',
#  'maraa',
#  'tulum',
#  'ondjiva',
#  'myitkyina',
#  'hirara',
#  'luanda',
#  'sinnamary',
#  'angoche',
#  'mujiayingzi',
#  'russell',
#  'newport',
#  'eldikan',
#  'pisco',
#  'marcona',
#  'katsuura',
#  'paramonga',
#  'saint-philippe',
#  'kaitangata',
#  'asyut',
#  'springfield',
#  'teahupoo',
#  'cristinapolis',
#  'port lincoln',
#  'sao filipe',
#  'harper',
#  'lavrentiya',
#  'severo-kurilsk',
#  'simbahan',
#  'hasaki',
#  'tabou',
#  'cherskiy',
#  'ambanja',
#  'nioki',
#  'gurupi',
#  'necochea',
#  'kihei',
#  'anton lizardo',
#  'kristiansund',
#  'slave lake',
#  'villanueva de cordoba',
#  'ixtapa',
#  'isangel',
#  'kaeo',
#  'hami',
#  'caceres',
#  'bilma',
#  'salinas',
#  'zhangye',
#  'tautira',
#  'werda',
#  'kemin',
#  'penzance',
#  'sabha',
#  'da nang',
#  'pangnirtung',
#  'iracoubo',
#  'lolua',
#  'san cristobal',
#  'rafai',
#  'changji',
#  'mandalgovi',
#  'mantua',
#  'koutselion',
#  'pozo colorado',
#  'avera',
#  'tilichiki',
#  'vila velha',
#  'meru',
#  'mago',
#  'satitoa',
#  'madang',
#  'saint-augustin',
#  'klyuchevskiy',
#  'boras',
#  'pau brasil',
#  'rungata',
#  'viru',
#  'sorland',
#  'puerto colombia',
#  'marsa matruh',
#  'sol-iletsk',
#  'broken hill',
#  'half moon bay',
#  'acajutla',
#  'bubaque',
#  'pangkalanbuun',
#  'dandong',
#  'lata',
#  'lompoc',
#  'stepnogorsk',
#  'lagoa',
#  'guadalajara',
#  'katherine',
#  'sisimiut',
#  'ranot',
#  'duayaw nkwanta',
#  'srednekolymsk',
#  'napasar',
#  'pevek',
#  'chifeng',
#  'wajir',
#  'canillo',
#  'tazovskiy',
#  'khormuj',
#  'bury saint edmunds',
#  'pictou',
#  'naron',
#  'canutama',
#  'waycross',
#  'shingu',
#  'sao jose da coroa grande',
#  'hobyo',
#  'madruga',
#  'geraldton',
#  'wasilla',
#  'mehamn',
#  'margate',
#  'gimli',
#  'asfi',
#  'chipinge',
#  'cheuskiny',
#  'ibirapitanga',
#  'saint anthony',
#  'camacha',
#  'san patricio',
#  'alta floresta',
#  'sola',
#  'trebinje',
#  'tema',
#  'okakarara',
#  'indramayu',
#  'sechura',
#  'waldoboro',
#  'morant bay',
#  'alpena',
#  'davila',
#  'rostaq',
#  'meulaboh',
#  'fukue',
#  'saint-francois',
#  'salalah',
#  'condado',
#  'solwezi',
#  'alakurtti',
#  'nuuk',
#  'alausi',
#  'yulara',
#  'vao',
#  'manaure',
#  'bukachacha',
#  'wanning',
#  'lewisporte',
#  'port-cartier',
#  'vung tau',
#  'ponce',
#  'bairiki',
#  'panguna',
#  'chimbote',
#  'sitka',
#  'vytegra',
#  'solenzo',
#  'muros',
#  'raga',
#  'la ronge',
#  'monte alegre',
#  'hambantota',
#  'mecca',
#  'guymon',
#  'cape elizabeth',
#  'kitakata',
#  'palabuhanratu',
#  'chapais',
#  'caxias',
#  'warqla',
#  'talara',
#  'udachnyy',
#  'santo amaro',
#  'qasigiannguit',
#  'ketchikan',
#  'sangmelima',
#  'rawlins',
#  'tucuma',
#  'makokou',
#  'westport',
#  'soyo',
#  'olinda',
#  'nome',
#  'moron',
#  'christchurch',
#  'asau',
#  'talcahuano',
#  'tall kayf',
#  'fjerritslev',
#  'kuching',
#  'tucano',
#  'quchan',
#  'benxi',
#  'komsomolskiy',
#  'palmer',
#  'bacungan',
#  'taunggyi',
#  'hurricane',
#  'huangchuan',
#  'letlhakeng',
#  'amurzet',
#  'kupang',
#  'panaba',
#  'solovetskiy',
#  'ulaanbaatar',
#  'ponta delgada',
#  'jalu',
#  'shenjiamen',
#  'dingle',
#  'lodhikheda',
#  'henties bay',
#  'sarahan',
#  'wexford',
#  'coahuayana',
#  'santiago del estero',
#  'sembakung',
#  'haines junction',
#  'pulsano',
#  'candelaria',
#  'matara',
#  'macaboboni',
#  'karratha',
#  'superior',
#  'okha',
#  'ayan',
#  'ruzhyn',
#  'pondicherry',
#  'bonavista',
#  'abalak',
#  'namatanai',
#  'nishihara',
#  'mbuguni',
#  'brigantine',
#  'ust-barguzin',
#  'talnakh',
#  'bodden town',
#  'ishigaki',
#  'sao felix do xingu',
#  'beira',
#  'pyu',
#  'carutapera',
#  'tricase',
#  'pleasant grove',
#  'kadykchan',
#  'dalbandin',
#  'copiapo',
#  'sarila',
#  'key largo',
#  'kumluca',
#  'krasnoselkup',
#  'barbar',
#  'aksehir',
#  'inuvik',
#  'oranjemund',
#  'lorengau',
#  'praya',
#  'taoudenni',
#  'atar',
#  'abha',
#  'yuli',
#  'labutta',
#  'arkhangelsk',
#  'honiara',
#  'mitsamiouli',
#  'roald',
#  'palembang',
#  'daman',
#  'linjiang',
#  'kodinar',
#  'orlik',
#  'barao de melgaco',
#  'kavaratti',
#  'jazzin',
#  'tsabong',
#  'abu samrah',
#  'salvador',
#  'abu kamal',
#  'matagami',
#  'zhezkazgan',
#  'luderitz',
#  'amapa',
#  'cairns',
#  'port antonio',
#  'almeirim',
#  'goroka',
#  'skjervoy',
#  'alto araguaia',
#  'san andres',
#  'katima mulilo',
#  'portland',
#  'turochak',
#  'takoradi',
#  'narsimhapur',
#  'dudinka',
#  'neiafu',
#  'cantavir',
#  'coos bay',
#  'rio tuba',
#  'buritis',
#  'ust-tsilma',
#  'homer',
#  'albufeira',
#  'umm kaddadah',
#  'iraucuba',
#  'huilong',
#  'chicama',
#  'acapulco',
#  'lingyuan',
#  'halifax',
#  'kaka',
#  'aklavik',
#  'aswan',
#  'vestmannaeyjar',
#  'cootamundra',
#  'ampanihy',
#  'la libertad',
#  'karasjok',
#  'swan hill',
#  'viedma',
#  'tutoia',
#  'sistranda',
#  'nauta',
#  'conakry',
#  'malwan',
#  'san pedro de macoris',
#  'aljezur',
#  'ambulu',
#  'bonfim',
#  'tenenkou',
#  'abbeville',
#  'pemangkat',
#  'susanville',
#  'dunedin',
#  'paltinis',
#  'benguela',
#  'kamen-rybolov',
#  'ambilobe',
#  'quatre cocos',
#  'kristianstad',
#  'fountain',
#  'aksu',
#  'duma']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url = api.openweathermap.org/data/2.5/
cities_test = ['noumea','hermanus','cabo san lucas','luderitz','buchanan','hobart','srandakan','esperance','saldanha','ushuaia',
 'zyryanka',
 'souillac']

city_weather_df = pd.DataFrame(columns=['City', 'Lat', 'Lng', 'Max Temp', 'Humidity',
                                        'Cloudiness', 'Wind Speed', 'Country', 'Date'])
count = 0
print('Begining City-Data Retrieval')
print('-----------------------------')

for city in cities:
    
    count=count+1
    print(f'Processing City {count} | {city}')
    target_url = ('http://api.openweathermap.org/data/2.5/weather?q={0}&units=imperial&appid={1}').format(city, weather_key)
    response = requests.get(target_url).json()
#     print(target_url)
    
    try:   
        lat = response["coord"]["lat"]
        lng = response["coord"]["lon"]
        max_temp = response["main"]["temp_max"]
        wind_speed = response["wind"]["speed"]
        clouds = response["clouds"]["all"]
        humidity = response["main"]["humidity"]
        country = response["sys"]["country"]
        date = response["dt"]
    
        city_weather_df = city_weather_df.append({'City':city,
                                              'Lat': lat,
                                              'Lng':lng,
                                              'Max Temp':max_temp,
                                              'Humidity':humidity,
                                              'Cloudiness':clouds,
                                              'Wind Speed':wind_speed,
                                              'Country':country,
                                              'Date':date},ignore_index=True)
        time.sleep(1.1)
    except:
            print('City not found. Skipping...')
            pass
# Out:
# Begining City-Data Retrieval
# -----------------------------
# Processing City 1 | kodiak
# Processing City 2 | te anau
# Processing City 3 | hobart
# Processing City 4 | umzimvubu
# City not found. Skipping...
# Processing City 5 | victoria
# Processing City 6 | mataura
# Processing City 7 | zyryanovsk
# Processing City 8 | taolanaro
# City not found. Skipping...
# Processing City 9 | oranjestad
# Processing City 10 | lipin bor
# Processing City 11 | mount gambier
# Processing City 12 | amderma
# City not found. Skipping...
# Processing City 13 | saskylakh
# Processing City 14 | leningradskiy
# Processing City 15 | oxford
# Processing City 16 | utete
# Processing City 17 | lebu
# Processing City 18 | saleaula
# City not found. Skipping...
# Processing City 19 | mahebourg
# Processing City 20 | taltal
# Processing City 21 | hilo
# Processing City 22 | auki
# Processing City 23 | tuktoyaktuk
# Processing City 24 | mayo
# Processing City 25 | rikitea
# Processing City 26 | gat
# Processing City 27 | semarang
# Processing City 28 | vaini
# Processing City 29 | saint george
# Processing City 30 | alice springs
# Processing City 31 | bluff
# Processing City 32 | chuy
# Processing City 33 | kaya
# Processing City 34 | attawapiskat
# City not found. Skipping...
# Processing City 35 | souillac
# Processing City 36 | cuiluan
# Processing City 37 | punta arenas
# Processing City 38 | lujan
# Processing City 39 | iqaluit
# Processing City 40 | ushuaia
# Processing City 41 | mar del plata
# Processing City 42 | wahiawa
# Processing City 43 | barrow
# Processing City 44 | ribeira grande
# Processing City 45 | port elizabeth
# Processing City 46 | cape town
# Processing City 47 | qaanaaq
# Processing City 48 | saldanha
# Processing City 49 | gravelbourg
# Processing City 50 | padang
# Processing City 51 | yellowknife
# Processing City 52 | tiksi
# Processing City 53 | guerrero negro
# Processing City 54 | pacific grove
# Processing City 55 | puerto del rosario
# Processing City 56 | port alfred
# Processing City 57 | muncar
# Processing City 58 | ponta do sol
# Processing City 59 | castro
# Processing City 60 | skibbereen
# Processing City 61 | laguna
# Processing City 62 | yumen
# Processing City 63 | pachino
# Processing City 64 | nikolskoye
# Processing City 65 | san pedro
# Processing City 66 | yerbogachen
# Processing City 67 | belushya guba
# City not found. Skipping...
# Processing City 68 | bassano
# Processing City 69 | carnarvon
# Processing City 70 | saint-pierre
# Processing City 71 | rossland
# Processing City 72 | barentsburg
# City not found. Skipping...
# Processing City 73 | airai
# Processing City 74 | kapaa
# Processing City 75 | dikson
# Processing City 76 | chateauroux
# Processing City 77 | yabelo
# Processing City 78 | puerto ayora
# Processing City 79 | arraial do cabo
# Processing City 80 | natal
# Processing City 81 | khatanga
# Processing City 82 | atuona
# Processing City 83 | bima
# Processing City 84 | cidreira
# Processing City 85 | sabang
# Processing City 86 | east london
# Processing City 87 | adrar
# Processing City 88 | busselton
# Processing City 89 | berlevag
# Processing City 90 | bathsheba
# Processing City 91 | albany
# Processing City 92 | cassilandia
# Processing City 93 | marsh harbour
# Processing City 94 | nadadores
# Processing City 95 | mount isa
# Processing City 96 | coquimbo
# Processing City 97 | klaksvik
# Processing City 98 | grand river south east
# City not found. Skipping...
# Processing City 99 | chumikan
# Processing City 100 | butaritari
# Processing City 101 | norman wells
# Processing City 102 | new norfolk
# Processing City 103 | upernavik
# Processing City 104 | xuddur
# Processing City 105 | ulladulla
# Processing City 106 | thompson
# Processing City 107 | zhigansk
# Processing City 108 | jamestown
# Processing City 109 | faya
# Processing City 110 | surt
# Processing City 111 | illoqqortoormiut
# City not found. Skipping...
# Processing City 112 | seoul
# Processing City 113 | cabo san lucas
# Processing City 114 | khonuu
# City not found. Skipping...
# Processing City 115 | kangalassy
# Processing City 116 | teya
# Processing City 117 | shediac
# Processing City 118 | ushtobe
# Processing City 119 | sun valley
# Processing City 120 | okhotsk
# Processing City 121 | nanortalik
# Processing City 122 | port hawkesbury
# Processing City 123 | vaitupu
# City not found. Skipping...
# Processing City 124 | lafia
# Processing City 125 | grindavik
# Processing City 126 | mys shmidta
# City not found. Skipping...
# Processing City 127 | jiangyin
# Processing City 128 | solnechnyy
# Processing City 129 | avarua
# Processing City 130 | pontianak
# Processing City 131 | clyde river
# Processing City 132 | ambon
# Processing City 133 | ilulissat
# Processing City 134 | general roca
# Processing City 135 | epe
# Processing City 136 | georgetown
# Processing City 137 | havoysund
# Processing City 138 | roebourne
# Processing City 139 | palu
# Processing City 140 | korla
# Processing City 141 | fortuna
# Processing City 142 | kamenskoye
# City not found. Skipping...
# Processing City 143 | varna
# Processing City 144 | cockburn town
# Processing City 145 | comodoro rivadavia
# Processing City 146 | bredasdorp
# Processing City 147 | the pas
# Processing City 148 | kahului
# Processing City 149 | chokurdakh
# Processing City 150 | bethel
# Processing City 151 | hamilton
# Processing City 152 | guelavia
# City not found. Skipping...
# Processing City 153 | gara
# Processing City 154 | port blair
# Processing City 155 | hithadhoo
# Processing City 156 | saint-paul
# Processing City 157 | ludvika
# Processing City 158 | mackay
# Processing City 159 | tessalit
# Processing City 160 | viransehir
# Processing City 161 | nelson bay
# Processing City 162 | dongobesh
# Processing City 163 | deputatskiy
# Processing City 164 | los llanos de aridane
# Processing City 165 | morondava
# Processing City 166 | halalo
# City not found. Skipping...
# Processing City 167 | yamada
# Processing City 168 | kamaishi
# Processing City 169 | peniche
# Processing City 170 | hovd
# Processing City 171 | sorvag
# City not found. Skipping...
# Processing City 172 | yelan
# Processing City 173 | rairangpur
# Processing City 174 | torbay
# Processing City 175 | glace bay
# Processing City 176 | aykhal
# Processing City 177 | talas
# Processing City 178 | faanui
# Processing City 179 | yuxia
# Processing City 180 | winchester
# Processing City 181 | lastoursville
# Processing City 182 | palm coast
# Processing City 183 | miraflores
# Processing City 184 | modasa
# Processing City 185 | hermanus
# Processing City 186 | zhaodong
# Processing City 187 | paamiut
# Processing City 188 | rengali
# Processing City 189 | kavieng
# Processing City 190 | bengkulu
# Processing City 191 | shakawe
# Processing City 192 | vila
# Processing City 193 | maniitsoq
# Processing City 194 | nenjiang
# Processing City 195 | alexandria
# Processing City 196 | ancud
# Processing City 197 | barcelos
# Processing City 198 | meyungs
# City not found. Skipping...
# Processing City 199 | cayenne
# Processing City 200 | santa rosa
# Processing City 201 | beringovskiy
# Processing City 202 | tuatapere
# Processing City 203 | batesville
# Processing City 204 | richards bay
# Processing City 205 | coihaique
# Processing City 206 | narsaq
# Processing City 207 | tasiilaq
# Processing City 208 | constitucion
# Processing City 209 | betania
# Processing City 210 | bambous virieux
# Processing City 211 | petrozavodsk
# Processing City 212 | galesburg
# Processing City 213 | rapar
# Processing City 214 | mendi
# Processing City 215 | rockland
# Processing City 216 | naze
# Processing City 217 | tabligbo
# Processing City 218 | marzuq
# Processing City 219 | leshukonskoye
# Processing City 220 | phun phin
# City not found. Skipping...
# Processing City 221 | sentyabrskiy
# City not found. Skipping...
# Processing City 222 | cabatuan
# Processing City 223 | longyearbyen
# Processing City 224 | malokakhovka
# Processing City 225 | flinders
# Processing City 226 | kazalinsk
# City not found. Skipping...
# Processing City 227 | lufilufi
# Processing City 228 | vangaindrano
# Processing City 229 | muli
# Processing City 230 | tual
# Processing City 231 | horten
# Processing City 232 | provideniya
# Processing City 233 | roma
# Processing City 234 | calabozo
# Processing City 235 | nemuro
# Processing City 236 | codrington
# Processing City 237 | daru
# Processing City 238 | achisay
# City not found. Skipping...
# Processing City 239 | kruisfontein
# Processing City 240 | galesong
# Processing City 241 | surskoye
# Processing City 242 | praia da vitoria
# Processing City 243 | umtata
# Processing City 244 | santa fe
# Processing City 245 | bastia
# Processing City 246 | weinan
# Processing City 247 | vardo
# Processing City 248 | huntsville
# Processing City 249 | inyonga
# Processing City 250 | loandjili
# Processing City 251 | sucre
# Processing City 252 | sobolevo
# Processing City 253 | waipawa
# Processing City 254 | vila franca do campo
# Processing City 255 | verkhoyansk
# Processing City 256 | san lawrenz
# Processing City 257 | surab
# Processing City 258 | toda raisingh
# Processing City 259 | tecoanapa
# Processing City 260 | bandundu
# Processing City 261 | labuhan
# Processing City 262 | linqiong
# Processing City 263 | mankono
# Processing City 264 | lazaro cardenas
# Processing City 265 | esperance
# Processing City 266 | beloha
# Processing City 267 | talaya
# Processing City 268 | porto novo
# Processing City 269 | qaqortoq
# Processing City 270 | batemans bay
# Processing City 271 | rio de janeiro
# Processing City 272 | nizhneyansk
# City not found. Skipping...
# Processing City 273 | mentok
# City not found. Skipping...
# Processing City 274 | maraa
# Processing City 275 | tulum
# Processing City 276 | ondjiva
# Processing City 277 | myitkyina
# Processing City 278 | hirara
# Processing City 279 | luanda
# Processing City 280 | sinnamary
# Processing City 281 | angoche
# Processing City 282 | mujiayingzi
# Processing City 283 | russell
# Processing City 284 | newport
# Processing City 285 | eldikan
# City not found. Skipping...
# Processing City 286 | pisco
# Processing City 287 | marcona
# City not found. Skipping...
# Processing City 288 | katsuura
# Processing City 289 | paramonga
# Processing City 290 | saint-philippe
# Processing City 291 | kaitangata
# Processing City 292 | asyut
# Processing City 293 | springfield
# Processing City 294 | teahupoo
# Processing City 295 | cristinapolis
# Processing City 296 | port lincoln
# Processing City 297 | sao filipe
# Processing City 298 | harper
# Processing City 299 | lavrentiya
# Processing City 300 | severo-kurilsk
# Processing City 301 | simbahan
# Processing City 302 | hasaki
# Processing City 303 | tabou
# Processing City 304 | cherskiy
# Processing City 305 | ambanja
# Processing City 306 | nioki
# Processing City 307 | gurupi
# Processing City 308 | necochea
# Processing City 309 | kihei
# Processing City 310 | anton lizardo
# Processing City 311 | kristiansund
# Processing City 312 | slave lake
# Processing City 313 | villanueva de cordoba
# Processing City 314 | ixtapa
# Processing City 315 | isangel
# Processing City 316 | kaeo
# Processing City 317 | hami
# Processing City 318 | caceres
# Processing City 319 | bilma
# Processing City 320 | salinas
# Processing City 321 | zhangye
# Processing City 322 | tautira
# Processing City 323 | werda
# Processing City 324 | kemin
# Processing City 325 | penzance
# Processing City 326 | sabha
# Processing City 327 | da nang
# Processing City 328 | pangnirtung
# Processing City 329 | iracoubo
# Processing City 330 | lolua
# City not found. Skipping...
# Processing City 331 | san cristobal
# Processing City 332 | rafai
# Processing City 333 | changji
# Processing City 334 | mandalgovi
# Processing City 335 | mantua
# Processing City 336 | koutselion
# Processing City 337 | pozo colorado
# Processing City 338 | avera
# Processing City 339 | tilichiki
# Processing City 340 | vila velha
# Processing City 341 | meru
# Processing City 342 | mago
# Processing City 343 | satitoa
# City not found. Skipping...
# Processing City 344 | madang
# Processing City 345 | saint-augustin
# Processing City 346 | klyuchevskiy
# Processing City 347 | boras
# Processing City 348 | pau brasil
# Processing City 349 | rungata
# City not found. Skipping...
# Processing City 350 | viru
# Processing City 351 | sorland
# Processing City 352 | puerto colombia
# Processing City 353 | marsa matruh
# Processing City 354 | sol-iletsk
# Processing City 355 | broken hill
# Processing City 356 | half moon bay
# Processing City 357 | acajutla
# Processing City 358 | bubaque
# Processing City 359 | pangkalanbuun
# Processing City 360 | dandong
# Processing City 361 | lata
# Processing City 362 | lompoc
# Processing City 363 | stepnogorsk
# Processing City 364 | lagoa
# Processing City 365 | guadalajara
# Processing City 366 | katherine
# Processing City 367 | sisimiut
# Processing City 368 | ranot
# Processing City 369 | duayaw nkwanta
# Processing City 370 | srednekolymsk
# Processing City 371 | napasar
# Processing City 372 | pevek
# Processing City 373 | chifeng
# Processing City 374 | wajir
# Processing City 375 | canillo
# Processing City 376 | tazovskiy
# Processing City 377 | khormuj
# City not found. Skipping...
# Processing City 378 | bury saint edmunds
# City not found. Skipping...
# Processing City 379 | pictou
# Processing City 380 | naron
# Processing City 381 | canutama
# Processing City 382 | waycross
# Processing City 383 | shingu
# Processing City 384 | sao jose da coroa grande
# Processing City 385 | hobyo
# Processing City 386 | madruga
# Processing City 387 | geraldton
# Processing City 388 | wasilla
# Processing City 389 | mehamn
# Processing City 390 | margate
# Processing City 391 | gimli
# Processing City 392 | asfi
# Processing City 393 | chipinge
# Processing City 394 | cheuskiny
# City not found. Skipping...
# Processing City 395 | ibirapitanga
# Processing City 396 | saint anthony
# Processing City 397 | camacha
# Processing City 398 | san patricio
# Processing City 399 | alta floresta
# Processing City 400 | sola
# Processing City 401 | trebinje
# Processing City 402 | tema
# Processing City 403 | okakarara
# Processing City 404 | indramayu
# Processing City 405 | sechura
# Processing City 406 | waldoboro
# Processing City 407 | morant bay
# Processing City 408 | alpena
# Processing City 409 | davila
# Processing City 410 | rostaq
# City not found. Skipping...
# Processing City 411 | meulaboh
# Processing City 412 | fukue
# Processing City 413 | saint-francois
# Processing City 414 | salalah
# Processing City 415 | condado
# Processing City 416 | solwezi
# Processing City 417 | alakurtti
# Processing City 418 | nuuk
# Processing City 419 | alausi
# Processing City 420 | yulara
# Processing City 421 | vao
# Processing City 422 | manaure
# Processing City 423 | bukachacha
# Processing City 424 | wanning
# Processing City 425 | lewisporte
# Processing City 426 | port-cartier
# Processing City 427 | vung tau
# Processing City 428 | ponce
# Processing City 429 | bairiki
# Processing City 430 | panguna
# Processing City 431 | chimbote
# Processing City 432 | sitka
# Processing City 433 | vytegra
# Processing City 434 | solenzo
# Processing City 435 | muros
# Processing City 436 | raga
# Processing City 437 | la ronge
# Processing City 438 | monte alegre
# Processing City 439 | hambantota
# Processing City 440 | mecca
# Processing City 441 | guymon
# Processing City 442 | cape elizabeth
# City not found. Skipping...
# Processing City 443 | kitakata
# Processing City 444 | palabuhanratu
# City not found. Skipping...
# Processing City 445 | chapais
# Processing City 446 | caxias
# Processing City 447 | warqla
# City not found. Skipping...
# Processing City 448 | talara
# Processing City 449 | udachnyy
# Processing City 450 | santo amaro
# Processing City 451 | qasigiannguit
# Processing City 452 | ketchikan
# Processing City 453 | sangmelima
# Processing City 454 | rawlins
# Processing City 455 | tucuma
# Processing City 456 | makokou
# Processing City 457 | westport
# Processing City 458 | soyo
# Processing City 459 | olinda
# Processing City 460 | nome
# Processing City 461 | moron
# Processing City 462 | christchurch
# Processing City 463 | asau
# Processing City 464 | talcahuano
# Processing City 465 | tall kayf
# Processing City 466 | fjerritslev
# Processing City 467 | kuching
# Processing City 468 | tucano
# Processing City 469 | quchan
# Processing City 470 | benxi
# Processing City 471 | komsomolskiy
# Processing City 472 | palmer
# Processing City 473 | bacungan
# Processing City 474 | taunggyi
# Processing City 475 | hurricane
# Processing City 476 | huangchuan
# Processing City 477 | letlhakeng
# Processing City 478 | amurzet
# Processing City 479 | kupang
# Processing City 480 | panaba
# Processing City 481 | solovetskiy
# City not found. Skipping...
# Processing City 482 | ulaanbaatar
# Processing City 483 | ponta delgada
# Processing City 484 | jalu
# Processing City 485 | shenjiamen
# Processing City 486 | dingle
# Processing City 487 | lodhikheda
# Processing City 488 | henties bay
# Processing City 489 | sarahan
# Processing City 490 | wexford
# Processing City 491 | coahuayana
# Processing City 492 | santiago del estero
# Processing City 493 | sembakung
# Processing City 494 | haines junction
# Processing City 495 | pulsano
# Processing City 496 | candelaria
# Processing City 497 | matara
# Processing City 498 | macaboboni
# City not found. Skipping...
# Processing City 499 | karratha
# Processing City 500 | superior
# Processing City 501 | okha
# Processing City 502 | ayan
# Processing City 503 | ruzhyn
# Processing City 504 | pondicherry
# Processing City 505 | bonavista
# Processing City 506 | abalak
# Processing City 507 | namatanai
# Processing City 508 | nishihara
# Processing City 509 | mbuguni
# Processing City 510 | brigantine
# Processing City 511 | ust-barguzin
# Processing City 512 | talnakh
# Processing City 513 | bodden town
# Processing City 514 | ishigaki
# Processing City 515 | sao felix do xingu
# Processing City 516 | beira
# Processing City 517 | pyu
# Processing City 518 | carutapera
# Processing City 519 | tricase
# Processing City 520 | pleasant grove
# Processing City 521 | kadykchan
# City not found. Skipping...
# Processing City 522 | dalbandin
# Processing City 523 | copiapo
# Processing City 524 | sarila
# Processing City 525 | key largo
# Processing City 526 | kumluca
# Processing City 527 | krasnoselkup
# Processing City 528 | barbar
# City not found. Skipping...
# Processing City 529 | aksehir
# Processing City 530 | inuvik
# Processing City 531 | oranjemund
# Processing City 532 | lorengau
# Processing City 533 | praya
# Processing City 534 | taoudenni
# Processing City 535 | atar
# Processing City 536 | abha
# Processing City 537 | yuli
# Processing City 538 | labutta
# City not found. Skipping...
# Processing City 539 | arkhangelsk
# Processing City 540 | honiara
# Processing City 541 | mitsamiouli
# Processing City 542 | roald
# Processing City 543 | palembang
# Processing City 544 | daman
# Processing City 545 | linjiang
# Processing City 546 | kodinar
# Processing City 547 | orlik
# Processing City 548 | barao de melgaco
# Processing City 549 | kavaratti
# Processing City 550 | jazzin
# City not found. Skipping...
# Processing City 551 | tsabong
# Processing City 552 | abu samrah
# Processing City 553 | salvador
# Processing City 554 | abu kamal
# Processing City 555 | matagami
# Processing City 556 | zhezkazgan
# Processing City 557 | luderitz
# Processing City 558 | amapa
# Processing City 559 | cairns
# Processing City 560 | port antonio
# Processing City 561 | almeirim
# Processing City 562 | goroka
# Processing City 563 | skjervoy
# Processing City 564 | alto araguaia
# Processing City 565 | san andres
# Processing City 566 | katima mulilo
# Processing City 567 | portland
# Processing City 568 | turochak
# Processing City 569 | takoradi
# Processing City 570 | narsimhapur
# Processing City 571 | dudinka
# Processing City 572 | neiafu
# Processing City 573 | cantavir
# Processing City 574 | coos bay
# Processing City 575 | rio tuba
# Processing City 576 | buritis
# Processing City 577 | ust-tsilma
# Processing City 578 | homer
# Processing City 579 | albufeira
# Processing City 580 | umm kaddadah
# Processing City 581 | iraucuba
# Processing City 582 | huilong
# Processing City 583 | chicama
# Processing City 584 | acapulco
# Processing City 585 | lingyuan
# Processing City 586 | halifax
# Processing City 587 | kaka
# Processing City 588 | aklavik
# Processing City 589 | aswan
# Processing City 590 | vestmannaeyjar
# Processing City 591 | cootamundra
# Processing City 592 | ampanihy
# Processing City 593 | la libertad
# Processing City 594 | karasjok
# Processing City 595 | swan hill
# Processing City 596 | viedma
# Processing City 597 | tutoia
# Processing City 598 | sistranda
# Processing City 599 | nauta
# Processing City 600 | conakry
# Processing City 601 | malwan
# City not found. Skipping...
# Processing City 602 | san pedro de macoris
# Processing City 603 | aljezur
# Processing City 604 | ambulu
# Processing City 605 | bonfim
# Processing City 606 | tenenkou
# Processing City 607 | abbeville
# Processing City 608 | pemangkat
# Processing City 609 | susanville
# Processing City 610 | dunedin
# Processing City 611 | paltinis
# Processing City 612 | benguela
# Processing City 613 | kamen-rybolov
# Processing City 614 | ambilobe
# Processing City 615 | quatre cocos
# Processing City 616 | kristianstad
# Processing City 617 | fountain
# Processing City 618 | aksu
# Processing City 619 | duma

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_df.to_csv("../Resources/Weather-data.csv")
city_weather_df.tail()
city_weather_df
# Out:
#              City    Lat     Lng  Max Temp Humidity Cloudiness  Wind Speed  \
# 572  quatre cocos -20.21   57.76     77.00       78         40       12.75
# 573  kristianstad  56.03   14.15     37.99      100        100        4.70
# 574      fountain  38.68 -104.70     37.00       59          1       13.87
# 575          aksu  41.12   80.26     15.55       91          0        2.77
# 576          duma  34.77  108.14     14.00       66          0        6.71
#
#     Country        Date
# 572      MU  1609273481
# 573      SE  1609273340
# 574      US  1609273282
# 575      CN  1609273485
# 576      CN  1609273486

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_weather_df[['Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Date']].astype(float).describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  577.000000  577.000000  577.000000  577.000000  577.000000  577.000000
# mean    19.539099   15.980260   51.638076   72.568458   51.230503    8.920416
# std     32.433291   89.995754   31.585733   18.511705   40.221529    6.636749
# min    -54.800000 -175.200000  -52.600000    9.000000    0.000000    0.490000
# 25%     -6.330000  -63.000000   33.800000   62.000000    4.000000    3.940000
# 50%     21.880000   17.370000   60.040000   77.000000   50.000000    7.000000
# 75%     45.520000  100.340000   77.000000   86.000000   94.000000   12.480000
# max     78.220000  179.320000  100.450000  100.000000  100.000000   44.760000
#
#                Date
# count  5.770000e+02
# mean   1.609273e+09
# std    2.295357e+02
# min    1.609272e+09
# 25%    1.609273e+09
# 50%    1.609273e+09
# 75%    1.609273e+09
# max    1.609273e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp_df = city_weather_df[['Lat','Max Temp']]
lat_temp_df

plt.rcParams["figure.figsize"] = (12, 6)
lat_temp_df.plot.scatter("Lat", "Max Temp", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="City Lattitude vs Max Temperature (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humidity_df = city_weather_df[['Lat','Humidity']]

plt.rcParams["figure.figsize"] = (12, 6)
lat_humidity_df.plot.scatter("Lat", "Humidity", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="City Lattitude vs Humidity (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloudiness_df = city_weather_df[['Lat','Cloudiness']]

plt.rcParams["figure.figsize"] = (12, 6)
lat_cloudiness_df.plot.scatter("Lat", "Cloudiness", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="City Lattitude vs Cloudiness (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (%)")
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_Wind_df = city_weather_df[['Lat','Wind Speed']]

plt.rcParams["figure.figsize"] = (12, 6)
lat_Wind_df.plot.scatter("Lat", "Wind Speed", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="City Lattitude vs Wind Speed (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
import scipy.stats as st
northern_df = city_weather_df.loc[city_weather_df['Lat']>=0]

x = northern_df['Lat']
y = northern_df['Max Temp']

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Max Temp", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Max Temp vs. Latitude Linear Regression", 
                         label="Temperatures")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(0,0),fontsize=20,color="red")
plt.ylabel('Max Temperature (F) ')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: -0.8207013113812136

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_df = city_weather_df.loc[city_weather_df['Lat']<0]

x = southern_df['Lat']
y = southern_df['Max Temp']

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Max Temp", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Max Temp vs. Latitude Linear Regression", 
                         label="Temperatures")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-20,52),fontsize=20,color="red")
plt.ylabel('Max Temperature (F) ')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: 0.44356316451208294

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Humidity'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Humidity", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Humidity(%)", 
                         label="Humidity(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(40,15),fontsize=20,color="red")
plt.ylabel('Humidity (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: 0.36453663426094607

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Humidity'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Humidity", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Humidity(%)", 
                         label="Humidity(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-20,15),fontsize=20,color="red")
plt.ylabel('Humidity (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: 0.21798252294563208

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Cloudiness'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Cloudiness", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Cloudiness (%)", 
                         label="Cloudiness(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(60,15),fontsize=20,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: 0.2450236521260761

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Cloudiness'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Cloudiness", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Cloudiness (%)", 
                         label="Cloudiness(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-55,10),fontsize=20,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: 0.24643624887022003

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Wind Speed'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Wind Speed", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Wind Speed (mph)", 
                         label="Wind Speed (mph)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(0,40),fontsize=20,color="red")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: 0.14063869210934496

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Wind Speed'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Wind Speed", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Wind Speed (mph)", 
                         label="Wind Speed (mph)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-38,22),fontsize=20,color="red")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
# Out:
# The r-value is: -0.1511036160533026
