# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['sentyabrskiy',
#  'port alfred',
#  'rocha',
#  'umm jarr',
#  'tsihombe',
#  'mataura',
#  'jamestown',
#  'vieste',
#  'puerto ayora',
#  'belle glade',
#  'rikitea',
#  'sadu',
#  'busselton',
#  'qaanaaq',
#  'sisophon',
#  'nikolskoye',
#  'cape town',
#  'meulaboh',
#  'forquilhinha',
#  'shar',
#  'bluff',
#  'kavieng',
#  'dakar',
#  'atuona',
#  'punta arenas',
#  'sorvag',
#  'arraial do cabo',
#  'tuktoyaktuk',
#  'kapaa',
#  'cherskiy',
#  'pacasmayo',
#  'georgetown',
#  'bambous virieux',
#  'the valley',
#  'druzhba',
#  'ponta do sol',
#  'concordia',
#  'goderich',
#  'nanortalik',
#  'avera',
#  'upernavik',
#  'bethel',
#  'borlange',
#  'tura',
#  'okhotsk',
#  'carnarvon',
#  'albany',
#  'parakou',
#  'ushuaia',
#  'khatanga',
#  'castro',
#  'liverpool',
#  'gunjur',
#  'yellowknife',
#  'ribeira grande',
#  'tiksi',
#  'norman wells',
#  'urumqi',
#  'san quintin',
#  'tasiilaq',
#  'zhob',
#  'chuy',
#  'barrow',
#  'nome',
#  'hobart',
#  'bredasdorp',
#  'hilo',
#  'adrar',
#  'hasaki',
#  'pitimbu',
#  'avarua',
#  'hamilton',
#  'grindavik',
#  'belushya guba',
#  'geraldton',
#  'mehamn',
#  'hithadhoo',
#  'seoul',
#  'lokachi',
#  'noumea',
#  'waingapu',
#  'henties bay',
#  'pochutla',
#  'vardo',
#  'new norfolk',
#  'pentecoste',
#  'dikson',
#  'illoqqortoormiut',
#  'taolanaro',
#  'malanje',
#  'severo-kurilsk',
#  'kodiak',
#  'palabuhanratu',
#  'constitucion',
#  'vostok',
#  'maralal',
#  'cayenne',
#  'hofn',
#  'cockburn town',
#  'makakilo city',
#  'saint-joseph',
#  'vaini',
#  'dunedin',
#  'we',
#  'port lincoln',
#  'guerrero negro',
#  'hare bay',
#  'taltal',
#  'korla',
#  'graaff-reinet',
#  'provideniya',
#  'lebu',
#  'lufilufi',
#  'hermanus',
#  'ancud',
#  'torbay',
#  'ngukurr',
#  'sinkat',
#  'qostanay',
#  'sibolga',
#  'wulanhaote',
#  'vaitupu',
#  'svetlaya',
#  'pevek',
#  'alofi',
#  'airai',
#  'belyy yar',
#  'rio cuarto',
#  'pietersburg',
#  'hays',
#  'furano',
#  'anchorage',
#  'gamboma',
#  'pangody',
#  'saldanha',
#  'mar del plata',
#  'banjar',
#  'martyush',
#  'victoria',
#  'saleaula',
#  'kamenka',
#  'montreal',
#  'boa vista',
#  'carahue',
#  'grand river south east',
#  'sorong',
#  'iquique',
#  'horsham',
#  'luderitz',
#  'narsaq',
#  'mantua',
#  'muros',
#  'clyde river',
#  'chokurdakh',
#  'zuwarah',
#  'kizukuri',
#  'teya',
#  'sabancuy',
#  'caceres',
#  'paka',
#  'mys shmidta',
#  'ekhabi',
#  'kloulklubed',
#  'camocim',
#  'mahebourg',
#  'mwinilunga',
#  'gopalur',
#  'ust-ishim',
#  'saint-philippe',
#  'isangel',
#  'aksay',
#  'ponta pora',
#  'saskylakh',
#  'longyearbyen',
#  'san francisco',
#  'mareeba',
#  'east london',
#  'kita',
#  'nouakchott',
#  'itarema',
#  'aanekoski',
#  'botucatu',
#  'axim',
#  'sauda',
#  'abnub',
#  'hida',
#  'kirakira',
#  'xapuri',
#  'berdigestyakh',
#  'tonantins',
#  'sao filipe',
#  'iqaluit',
#  'krasnoselkup',
#  'petropavlovsk-kamchatskiy',
#  'ketchikan',
#  'olafsvik',
#  'oriximina',
#  'vila franca do campo',
#  'ahipara',
#  'coquimbo',
#  'thompson',
#  'amderma',
#  'kananga',
#  'uruzgan',
#  'livingston',
#  'kalat',
#  'san vicente',
#  'kenmare',
#  'ivybridge',
#  'mbala',
#  'sain alto',
#  'tavda',
#  'butaritari',
#  'san luis',
#  'belaya gora',
#  'esperance',
#  'angoram',
#  'yanan',
#  'hobyo',
#  'yinchuan',
#  'labis',
#  'uaua',
#  'ponta delgada',
#  'sitka',
#  'naze',
#  'abu jubayhah',
#  'jogindarnagar',
#  'bereznik',
#  'mendoza',
#  'yulara',
#  'tawau',
#  'brewster',
#  'dingle',
#  'cabo san lucas',
#  'viedma',
#  'carmen',
#  'tula',
#  'marfino',
#  'aginskoye',
#  'barentsburg',
#  'bengkulu',
#  'aykhal',
#  'riyadh',
#  'mandalay',
#  'tezu',
#  'tidore',
#  'presidencia roque saenz pena',
#  'haines junction',
#  'portree',
#  'lucapa',
#  'buala',
#  'ondjiva',
#  'ambunti',
#  'salalah',
#  'lincoln',
#  'nueva guinea',
#  'yashan',
#  'husavik',
#  'varhaug',
#  'auki',
#  'rosarito',
#  'lagoa',
#  'aklavik',
#  'lavrentiya',
#  'faanui',
#  'marcona',
#  'kemijarvi',
#  'bangui',
#  'port elizabeth',
#  'attawapiskat',
#  'tashla',
#  'bolonchen',
#  'bara',
#  'skjervoy',
#  'ilskiy',
#  'la ronge',
#  'laukaa',
#  'yefimovskiy',
#  'sungaipenuh',
#  'kaliua',
#  'codrington',
#  'souillac',
#  'kasempa',
#  'kruisfontein',
#  'meyungs',
#  'montego bay',
#  'teseney',
#  'bystryy istok',
#  'ahome',
#  'port hedland',
#  'willowmore',
#  'bundaberg',
#  'san jose',
#  'fort frances',
#  'sao joao da barra',
#  'san cristobal',
#  'chapais',
#  'komyshuvakha',
#  'tungor',
#  'baoying',
#  'san miguel',
#  'bendigo',
#  'maldonado',
#  'erenhot',
#  'leh',
#  'nizhneyansk',
#  'puerto cabezas',
#  'awassa',
#  'lompoc',
#  'aripuana',
#  'mount gambier',
#  'yambio',
#  'sao teotonio',
#  'havre',
#  'shenjiamen',
#  'los llanos de aridane',
#  'high rock',
#  'puerto ayacucho',
#  'krasnaya gorbatka',
#  'san juan',
#  'barawe',
#  'sechura',
#  'iwaki',
#  'simpang',
#  'sakakah',
#  'bathsheba',
#  'xuddur',
#  'manjacaze',
#  'kahului',
#  'stony brook',
#  'bandarbeyla',
#  'mao',
#  'adre',
#  'acapulco',
#  'louisbourg',
#  'sahawar',
#  'ligayan',
#  'olinda',
#  'rondonopolis',
#  'saint anthony',
#  'kolondieba',
#  'wahiawa',
#  'pozo colorado',
#  'port hawkesbury',
#  'eldoret',
#  'poum',
#  'kongolo',
#  'katsuura',
#  'namibe',
#  'kenai',
#  'guymon',
#  'phalaborwa',
#  'russell',
#  'leningradskiy',
#  'paamiut',
#  'kabalo',
#  'muisne',
#  'boguchany',
#  'grahamstown',
#  'skibbereen',
#  'kangaba',
#  'touros',
#  'aranos',
#  'sherbakul',
#  'pisco',
#  'umzimvubu',
#  'saint-augustin',
#  'haverfordwest',
#  'tautira',
#  'jurilovca',
#  'brae',
#  'samusu',
#  'barra patuca',
#  'chateaubelair',
#  'varkkallai',
#  'waipawa',
#  'vaxjo',
#  'surgut',
#  'tsiroanomandidy',
#  'bartica',
#  'caravelas',
#  'komsomolskiy',
#  'anadyr',
#  'carballo',
#  'bulalacao',
#  'kutum',
#  'cedar city',
#  'srandakan',
#  'rincon',
#  'oktyabrskoye',
#  'phetchabun',
#  'arman',
#  'ilulissat',
#  'santana do matos',
#  'nishihara',
#  'tuatapere',
#  'kapuskasing',
#  'thinadhoo',
#  'najran',
#  'high level',
#  'namtsy',
#  'omsukchan',
#  'coxim',
#  'samarai',
#  'saint george',
#  'korfovskiy',
#  'bhadasar',
#  'marabba',
#  'otautau',
#  'kachiry',
#  'juybar',
#  'brigantine',
#  'atar',
#  'hervey bay',
#  'do rud',
#  'cidreira',
#  'lolua',
#  'san antonio',
#  'richards bay',
#  'sobolevo',
#  'stornoway',
#  'oron',
#  'ust-kuyga',
#  'wanning',
#  'tumannyy',
#  'half moon bay',
#  'taburi',
#  'vao',
#  'krasnoyarskiy',
#  'port macquarie',
#  'padang',
#  'matola',
#  'kuche',
#  'westport',
#  'yurty',
#  'the pas',
#  'den helder',
#  'yerofey pavlovich',
#  'klaksvik',
#  'panaba',
#  'marawi',
#  'elat',
#  'northam',
#  'ostersund',
#  'labuhan',
#  'shahrud',
#  'talnakh',
#  'krasnaya poyma',
#  'beloha',
#  'wewak',
#  'shitanjing',
#  'bubaque',
#  'urdzhar',
#  'blagoveshchensk',
#  'shache',
#  'barcelos',
#  'lohja',
#  'ayorou',
#  'villa union',
#  'prescott',
#  'srednekolymsk',
#  'flin flon',
#  'ipil',
#  'providencia',
#  'domoni',
#  'tawkar',
#  'shimoda',
#  'avanigadda',
#  'ahuimanu',
#  'golden',
#  'portland',
#  'margate',
#  'muli',
#  'blyth',
#  'bonavista',
#  'jinka',
#  'imabari',
#  'moose factory',
#  'rio grande',
#  'hovd',
#  'vaijapur',
#  'oistins',
#  'monze',
#  'necochea',
#  'mount darwin',
#  'hualmay',
#  'pocone',
#  'adelaide',
#  'laguna',
#  'lugovoy',
#  'gigmoto',
#  'antalaha',
#  'san ignacio',
#  'wakkanai',
#  'huaraz',
#  'alice springs',
#  'basco',
#  'san patricio',
#  'pak phanang',
#  'nemuro',
#  'morondava',
#  'ola',
#  'coihaique',
#  'winnemucca',
#  'datia',
#  'tungkang',
#  'takoradi',
#  'genoa',
#  'aldergrove',
#  'kieta',
#  'great falls',
#  'chivilcoy',
#  'uwayl',
#  'sumbawa',
#  'aksarka',
#  'bur gabo',
#  'sao jose da coroa grande',
#  'dubti',
#  'houma',
#  'hambantota',
#  'port augusta',
#  'santa marta de tormes',
#  'praxedis guerrero',
#  'huntsville',
#  'tekeli',
#  'trairi',
#  'saint-francois',
#  'churumuco',
#  'tilichiki',
#  'paulo afonso',
#  'palana',
#  'luau',
#  'sao joaquim',
#  'rancho palos verdes',
#  'jambi',
#  'inverell',
#  'kaitangata',
#  'anloga',
#  'kushtagi',
#  'kirovskiy',
#  'bolitoc',
#  'nadym',
#  'phonhong',
#  'cameta',
#  'helena',
#  'sao francisco',
#  'puerto suarez',
#  'agirish',
#  'tankhoy',
#  'dandong',
#  'oktyabrskiy',
#  'kushima',
#  'kenora',
#  'derzhavinsk',
#  'port blair',
#  'yuanping',
#  'samalaeulu',
#  'broome',
#  'arona',
#  'asau',
#  'ust-bolsheretsk',
#  'nakhon thai',
#  'sistranda',
#  'lasa',
#  'ternate',
#  'gangotri',
#  'aleppo',
#  'jumla',
#  'baykit',
#  'kavaratti',
#  'daru',
#  'zhezkazgan',
#  'diffa',
#  'lorengau',
#  'nawabganj',
#  'bonnyville',
#  'linhares',
#  'ordynskoye',
#  'kamina',
#  'porto santo',
#  'linqiong',
#  'okha',
#  'yar-sale',
#  'omboue',
#  'springdale',
#  'bethanien',
#  'guanica',
#  'fairbanks',
#  'lata',
#  'bilibino',
#  'imbituba',
#  'oranjestad',
#  'xinyang',
#  'andenes',
#  'sumbe',
#  'cancun',
#  'herat',
#  'tortoli',
#  'huarmey',
#  'almeirim',
#  'santa fe',
#  'walvis bay',
#  'bathurst',
#  'luganville',
#  'szczecinek']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url = api.openweathermap.org/data/2.5/
cities_test = ['noumea','hermanus','cabo san lucas','luderitz','buchanan','hobart','srandakan','esperance','saldanha','ushuaia',
 'zyryanka', 'souillac']

city_weather_df = pd.DataFrame(columns=['City', 'Lat', 'Lng', 'Max Temp', 'Humidity',
                                        'Cloudiness', 'Wind Speed', 'Country', 'Date'])
count = 0
print('Begining City-Data Retrieval')
print('-----------------------------')

for city in cities:
    
    count=count+1
    print(f'Processing City {count} | {city}')
    target_url = ('http://api.openweathermap.org/data/2.5/weather?q={0}&units=imperial&appid={1}').format(city, weather_key)
    response = requests.get(target_url).json()
#     print(target_url)
    
    try:   
        lat = response["coord"]["lat"]
        lng = response["coord"]["lon"]
        max_temp = response["main"]["temp_max"]
        wind_speed = response["wind"]["speed"]
        clouds = response["clouds"]["all"]
        humidity = response["main"]["humidity"]
        country = response["sys"]["country"]
        date = response["dt"]
    
        city_weather_df = city_weather_df.append({'City':city,
                                              'Lat': lat,
                                              'Lng':lng,
                                              'Max Temp':max_temp,
                                              'Humidity':humidity,
                                              'Cloudiness':clouds,
                                              'Wind Speed':wind_speed,
                                              'Country':country,
                                              'Date':date},ignore_index=True)
        time.sleep(1.1)
    except:
            print('City not found. Skipping...')
            pass
# Out:
# Begining City-Data Retrieval
# -----------------------------
# Processing City 1 | sentyabrskiy
# City not found. Skipping...
# Processing City 2 | port alfred
# Processing City 3 | rocha
# Processing City 4 | umm jarr
# City not found. Skipping...
# Processing City 5 | tsihombe
# City not found. Skipping...
# Processing City 6 | mataura
# Processing City 7 | jamestown
# Processing City 8 | vieste
# Processing City 9 | puerto ayora
# Processing City 10 | belle glade
# Processing City 11 | rikitea
# Processing City 12 | sadu
# Processing City 13 | busselton
# Processing City 14 | qaanaaq
# Processing City 15 | sisophon
# Processing City 16 | nikolskoye
# Processing City 17 | cape town
# Processing City 18 | meulaboh
# Processing City 19 | forquilhinha
# Processing City 20 | shar
# Processing City 21 | bluff
# Processing City 22 | kavieng
# Processing City 23 | dakar
# Processing City 24 | atuona
# Processing City 25 | punta arenas
# Processing City 26 | sorvag
# City not found. Skipping...
# Processing City 27 | arraial do cabo
# Processing City 28 | tuktoyaktuk
# Processing City 29 | kapaa
# Processing City 30 | cherskiy
# Processing City 31 | pacasmayo
# Processing City 32 | georgetown
# Processing City 33 | bambous virieux
# Processing City 34 | the valley
# Processing City 35 | druzhba
# Processing City 36 | ponta do sol
# Processing City 37 | concordia
# Processing City 38 | goderich
# Processing City 39 | nanortalik
# Processing City 40 | avera
# Processing City 41 | upernavik
# Processing City 42 | bethel
# Processing City 43 | borlange
# City not found. Skipping...
# Processing City 44 | tura
# Processing City 45 | okhotsk
# Processing City 46 | carnarvon
# Processing City 47 | albany
# Processing City 48 | parakou
# Processing City 49 | ushuaia
# Processing City 50 | khatanga
# Processing City 51 | castro
# Processing City 52 | liverpool
# Processing City 53 | gunjur
# Processing City 54 | yellowknife
# Processing City 55 | ribeira grande
# Processing City 56 | tiksi
# Processing City 57 | norman wells
# Processing City 58 | urumqi
# Processing City 59 | san quintin
# Processing City 60 | tasiilaq
# Processing City 61 | zhob
# Processing City 62 | chuy
# Processing City 63 | barrow
# Processing City 64 | nome
# Processing City 65 | hobart
# Processing City 66 | bredasdorp
# Processing City 67 | hilo
# Processing City 68 | adrar
# Processing City 69 | hasaki
# Processing City 70 | pitimbu
# Processing City 71 | avarua
# Processing City 72 | hamilton
# Processing City 73 | grindavik
# Processing City 74 | belushya guba
# City not found. Skipping...
# Processing City 75 | geraldton
# Processing City 76 | mehamn
# Processing City 77 | hithadhoo
# Processing City 78 | seoul
# Processing City 79 | lokachi
# Processing City 80 | noumea
# Processing City 81 | waingapu
# Processing City 82 | henties bay
# Processing City 83 | pochutla
# Processing City 84 | vardo
# Processing City 85 | new norfolk
# Processing City 86 | pentecoste
# Processing City 87 | dikson
# Processing City 88 | illoqqortoormiut
# City not found. Skipping...
# Processing City 89 | taolanaro
# City not found. Skipping...
# Processing City 90 | malanje
# Processing City 91 | severo-kurilsk
# Processing City 92 | kodiak
# Processing City 93 | palabuhanratu
# City not found. Skipping...
# Processing City 94 | constitucion
# Processing City 95 | vostok
# Processing City 96 | maralal
# Processing City 97 | cayenne
# Processing City 98 | hofn
# Processing City 99 | cockburn town
# Processing City 100 | makakilo city
# Processing City 101 | saint-joseph
# Processing City 102 | vaini
# Processing City 103 | dunedin
# Processing City 104 | we
# City not found. Skipping...
# Processing City 105 | port lincoln
# Processing City 106 | guerrero negro
# Processing City 107 | hare bay
# Processing City 108 | taltal
# Processing City 109 | korla
# Processing City 110 | graaff-reinet
# Processing City 111 | provideniya
# Processing City 112 | lebu
# Processing City 113 | lufilufi
# Processing City 114 | hermanus
# Processing City 115 | ancud
# Processing City 116 | torbay
# Processing City 117 | ngukurr
# City not found. Skipping...
# Processing City 118 | sinkat
# City not found. Skipping...
# Processing City 119 | qostanay
# Processing City 120 | sibolga
# Processing City 121 | wulanhaote
# City not found. Skipping...
# Processing City 122 | vaitupu
# City not found. Skipping...
# Processing City 123 | svetlaya
# Processing City 124 | pevek
# Processing City 125 | alofi
# Processing City 126 | airai
# Processing City 127 | belyy yar
# Processing City 128 | rio cuarto
# Processing City 129 | pietersburg
# Processing City 130 | hays
# Processing City 131 | furano
# Processing City 132 | anchorage
# Processing City 133 | gamboma
# Processing City 134 | pangody
# Processing City 135 | saldanha
# Processing City 136 | mar del plata
# Processing City 137 | banjar
# Processing City 138 | martyush
# Processing City 139 | victoria
# Processing City 140 | saleaula
# City not found. Skipping...
# Processing City 141 | kamenka
# Processing City 142 | montreal
# Processing City 143 | boa vista
# Processing City 144 | carahue
# Processing City 145 | grand river south east
# City not found. Skipping...
# Processing City 146 | sorong
# Processing City 147 | iquique
# Processing City 148 | horsham
# Processing City 149 | luderitz
# Processing City 150 | narsaq
# Processing City 151 | mantua
# Processing City 152 | muros
# Processing City 153 | clyde river
# Processing City 154 | chokurdakh
# Processing City 155 | zuwarah
# Processing City 156 | kizukuri
# Processing City 157 | teya
# Processing City 158 | sabancuy
# Processing City 159 | caceres
# Processing City 160 | paka
# Processing City 161 | mys shmidta
# City not found. Skipping...
# Processing City 162 | ekhabi
# Processing City 163 | kloulklubed
# Processing City 164 | camocim
# Processing City 165 | mahebourg
# Processing City 166 | mwinilunga
# Processing City 167 | gopalur
# Processing City 168 | ust-ishim
# Processing City 169 | saint-philippe
# Processing City 170 | isangel
# Processing City 171 | aksay
# Processing City 172 | ponta pora
# Processing City 173 | saskylakh
# Processing City 174 | longyearbyen
# Processing City 175 | san francisco
# Processing City 176 | mareeba
# Processing City 177 | east london
# Processing City 178 | kita
# Processing City 179 | nouakchott
# Processing City 180 | itarema
# Processing City 181 | aanekoski
# Processing City 182 | botucatu
# Processing City 183 | axim
# Processing City 184 | sauda
# Processing City 185 | abnub
# Processing City 186 | hida
# Processing City 187 | kirakira
# Processing City 188 | xapuri
# Processing City 189 | berdigestyakh
# Processing City 190 | tonantins
# Processing City 191 | sao filipe
# Processing City 192 | iqaluit
# Processing City 193 | krasnoselkup
# Processing City 194 | petropavlovsk-kamchatskiy
# Processing City 195 | ketchikan
# Processing City 196 | olafsvik
# Processing City 197 | oriximina
# Processing City 198 | vila franca do campo
# Processing City 199 | ahipara
# Processing City 200 | coquimbo
# Processing City 201 | thompson
# Processing City 202 | amderma
# City not found. Skipping...
# Processing City 203 | kananga
# Processing City 204 | uruzgan
# Processing City 205 | livingston
# Processing City 206 | kalat
# Processing City 207 | san vicente
# Processing City 208 | kenmare
# Processing City 209 | ivybridge
# Processing City 210 | mbala
# Processing City 211 | sain alto
# Processing City 212 | tavda
# Processing City 213 | butaritari
# Processing City 214 | san luis
# Processing City 215 | belaya gora
# Processing City 216 | esperance
# Processing City 217 | angoram
# Processing City 218 | yanan
# City not found. Skipping...
# Processing City 219 | hobyo
# Processing City 220 | yinchuan
# Processing City 221 | labis
# Processing City 222 | uaua
# Processing City 223 | ponta delgada
# Processing City 224 | sitka
# Processing City 225 | naze
# Processing City 226 | abu jubayhah
# City not found. Skipping...
# Processing City 227 | jogindarnagar
# Processing City 228 | bereznik
# Processing City 229 | mendoza
# Processing City 230 | yulara
# Processing City 231 | tawau
# Processing City 232 | brewster
# Processing City 233 | dingle
# Processing City 234 | cabo san lucas
# Processing City 235 | viedma
# Processing City 236 | carmen
# Processing City 237 | tula
# Processing City 238 | marfino
# Processing City 239 | aginskoye
# Processing City 240 | barentsburg
# City not found. Skipping...
# Processing City 241 | bengkulu
# Processing City 242 | aykhal
# Processing City 243 | riyadh
# Processing City 244 | mandalay
# Processing City 245 | tezu
# Processing City 246 | tidore
# City not found. Skipping...
# Processing City 247 | presidencia roque saenz pena
# Processing City 248 | haines junction
# Processing City 249 | portree
# Processing City 250 | lucapa
# Processing City 251 | buala
# Processing City 252 | ondjiva
# Processing City 253 | ambunti
# Processing City 254 | salalah
# Processing City 255 | lincoln
# Processing City 256 | nueva guinea
# Processing City 257 | yashan
# Processing City 258 | husavik
# Processing City 259 | varhaug
# Processing City 260 | auki
# Processing City 261 | rosarito
# Processing City 262 | lagoa
# Processing City 263 | aklavik
# Processing City 264 | lavrentiya
# Processing City 265 | faanui
# Processing City 266 | marcona
# City not found. Skipping...
# Processing City 267 | kemijarvi
# Processing City 268 | bangui
# Processing City 269 | port elizabeth
# Processing City 270 | attawapiskat
# City not found. Skipping...
# Processing City 271 | tashla
# Processing City 272 | bolonchen
# City not found. Skipping...
# Processing City 273 | bara
# Processing City 274 | skjervoy
# Processing City 275 | ilskiy
# Processing City 276 | la ronge
# Processing City 277 | laukaa
# Processing City 278 | yefimovskiy
# City not found. Skipping...
# Processing City 279 | sungaipenuh
# Processing City 280 | kaliua
# Processing City 281 | codrington
# Processing City 282 | souillac
# Processing City 283 | kasempa
# Processing City 284 | kruisfontein
# Processing City 285 | meyungs
# City not found. Skipping...
# Processing City 286 | montego bay
# Processing City 287 | teseney
# Processing City 288 | bystryy istok
# Processing City 289 | ahome
# Processing City 290 | port hedland
# Processing City 291 | willowmore
# Processing City 292 | bundaberg
# Processing City 293 | san jose
# Processing City 294 | fort frances
# Processing City 295 | sao joao da barra
# Processing City 296 | san cristobal
# Processing City 297 | chapais
# Processing City 298 | komyshuvakha
# Processing City 299 | tungor
# Processing City 300 | baoying
# Processing City 301 | san miguel
# Processing City 302 | bendigo
# Processing City 303 | maldonado
# Processing City 304 | erenhot
# Processing City 305 | leh
# Processing City 306 | nizhneyansk
# City not found. Skipping...
# Processing City 307 | puerto cabezas
# Processing City 308 | awassa
# Processing City 309 | lompoc
# Processing City 310 | aripuana
# Processing City 311 | mount gambier
# Processing City 312 | yambio
# Processing City 313 | sao teotonio
# Processing City 314 | havre
# Processing City 315 | shenjiamen
# Processing City 316 | los llanos de aridane
# Processing City 317 | high rock
# Processing City 318 | puerto ayacucho
# Processing City 319 | krasnaya gorbatka
# Processing City 320 | san juan
# Processing City 321 | barawe
# City not found. Skipping...
# Processing City 322 | sechura
# Processing City 323 | iwaki
# Processing City 324 | simpang
# Processing City 325 | sakakah
# Processing City 326 | bathsheba
# Processing City 327 | xuddur
# Processing City 328 | manjacaze
# Processing City 329 | kahului
# Processing City 330 | stony brook
# Processing City 331 | bandarbeyla
# Processing City 332 | mao
# Processing City 333 | adre
# Processing City 334 | acapulco
# Processing City 335 | louisbourg
# City not found. Skipping...
# Processing City 336 | sahawar
# Processing City 337 | ligayan
# Processing City 338 | olinda
# Processing City 339 | rondonopolis
# Processing City 340 | saint anthony
# Processing City 341 | kolondieba
# Processing City 342 | wahiawa
# Processing City 343 | pozo colorado
# Processing City 344 | port hawkesbury
# Processing City 345 | eldoret
# Processing City 346 | poum
# Processing City 347 | kongolo
# Processing City 348 | katsuura
# Processing City 349 | namibe
# Processing City 350 | kenai
# Processing City 351 | guymon
# Processing City 352 | phalaborwa
# Processing City 353 | russell
# Processing City 354 | leningradskiy
# Processing City 355 | paamiut
# Processing City 356 | kabalo
# Processing City 357 | muisne
# Processing City 358 | boguchany
# Processing City 359 | grahamstown
# Processing City 360 | skibbereen
# Processing City 361 | kangaba
# Processing City 362 | touros
# Processing City 363 | aranos
# Processing City 364 | sherbakul
# Processing City 365 | pisco
# Processing City 366 | umzimvubu
# City not found. Skipping...
# Processing City 367 | saint-augustin
# Processing City 368 | haverfordwest
# Processing City 369 | tautira
# Processing City 370 | jurilovca
# Processing City 371 | brae
# Processing City 372 | samusu
# City not found. Skipping...
# Processing City 373 | barra patuca
# Processing City 374 | chateaubelair
# Processing City 375 | varkkallai
# Processing City 376 | waipawa
# Processing City 377 | vaxjo
# Processing City 378 | surgut
# Processing City 379 | tsiroanomandidy
# Processing City 380 | bartica
# Processing City 381 | caravelas
# Processing City 382 | komsomolskiy
# Processing City 383 | anadyr
# Processing City 384 | carballo
# Processing City 385 | bulalacao
# Processing City 386 | kutum
# Processing City 387 | cedar city
# Processing City 388 | srandakan
# Processing City 389 | rincon
# Processing City 390 | oktyabrskoye
# Processing City 391 | phetchabun
# Processing City 392 | arman
# Processing City 393 | ilulissat
# Processing City 394 | santana do matos
# Processing City 395 | nishihara
# Processing City 396 | tuatapere
# Processing City 397 | kapuskasing
# Processing City 398 | thinadhoo
# Processing City 399 | najran
# Processing City 400 | high level
# Processing City 401 | namtsy
# Processing City 402 | omsukchan
# Processing City 403 | coxim
# Processing City 404 | samarai
# Processing City 405 | saint george
# Processing City 406 | korfovskiy
# Processing City 407 | bhadasar
# Processing City 408 | marabba
# Processing City 409 | otautau
# Processing City 410 | kachiry
# Processing City 411 | juybar
# Processing City 412 | brigantine
# Processing City 413 | atar
# Processing City 414 | hervey bay
# Processing City 415 | do rud
# City not found. Skipping...
# Processing City 416 | cidreira
# Processing City 417 | lolua
# City not found. Skipping...
# Processing City 418 | san antonio
# Processing City 419 | richards bay
# Processing City 420 | sobolevo
# Processing City 421 | stornoway
# Processing City 422 | oron
# Processing City 423 | ust-kuyga
# Processing City 424 | wanning
# Processing City 425 | tumannyy
# City not found. Skipping...
# Processing City 426 | half moon bay
# Processing City 427 | taburi
# City not found. Skipping...
# Processing City 428 | vao
# Processing City 429 | krasnoyarskiy
# Processing City 430 | port macquarie
# Processing City 431 | padang
# Processing City 432 | matola
# Processing City 433 | kuche
# City not found. Skipping...
# Processing City 434 | westport
# Processing City 435 | yurty
# Processing City 436 | the pas
# Processing City 437 | den helder
# Processing City 438 | yerofey pavlovich
# Processing City 439 | klaksvik
# Processing City 440 | panaba
# Processing City 441 | marawi
# Processing City 442 | elat
# Processing City 443 | northam
# Processing City 444 | ostersund
# Processing City 445 | labuhan
# Processing City 446 | shahrud
# Processing City 447 | talnakh
# Processing City 448 | krasnaya poyma
# Processing City 449 | beloha
# Processing City 450 | wewak
# Processing City 451 | shitanjing
# Processing City 452 | bubaque
# Processing City 453 | urdzhar
# City not found. Skipping...
# Processing City 454 | blagoveshchensk
# Processing City 455 | shache
# Processing City 456 | barcelos
# Processing City 457 | lohja
# Processing City 458 | ayorou
# Processing City 459 | villa union
# Processing City 460 | prescott
# Processing City 461 | srednekolymsk
# Processing City 462 | flin flon
# Processing City 463 | ipil
# Processing City 464 | providencia
# Processing City 465 | domoni
# Processing City 466 | tawkar
# City not found. Skipping...
# Processing City 467 | shimoda
# Processing City 468 | avanigadda
# Processing City 469 | ahuimanu
# Processing City 470 | golden
# Processing City 471 | portland
# Processing City 472 | margate
# Processing City 473 | muli
# Processing City 474 | blyth
# Processing City 475 | bonavista
# Processing City 476 | jinka
# Processing City 477 | imabari
# City not found. Skipping...
# Processing City 478 | moose factory
# Processing City 479 | rio grande
# Processing City 480 | hovd
# Processing City 481 | vaijapur
# Processing City 482 | oistins
# Processing City 483 | monze
# Processing City 484 | necochea
# Processing City 485 | mount darwin
# Processing City 486 | hualmay
# Processing City 487 | pocone
# Processing City 488 | adelaide
# Processing City 489 | laguna
# Processing City 490 | lugovoy
# Processing City 491 | gigmoto
# Processing City 492 | antalaha
# Processing City 493 | san ignacio
# Processing City 494 | wakkanai
# Processing City 495 | huaraz
# Processing City 496 | alice springs
# Processing City 497 | basco
# Processing City 498 | san patricio
# Processing City 499 | pak phanang
# Processing City 500 | nemuro
# Processing City 501 | morondava
# Processing City 502 | ola
# Processing City 503 | coihaique
# Processing City 504 | winnemucca
# Processing City 505 | datia
# Processing City 506 | tungkang
# City not found. Skipping...
# Processing City 507 | takoradi
# Processing City 508 | genoa
# Processing City 509 | aldergrove
# Processing City 510 | kieta
# Processing City 511 | great falls
# Processing City 512 | chivilcoy
# Processing City 513 | uwayl
# City not found. Skipping...
# Processing City 514 | sumbawa
# City not found. Skipping...
# Processing City 515 | aksarka
# Processing City 516 | bur gabo
# City not found. Skipping...
# Processing City 517 | sao jose da coroa grande
# Processing City 518 | dubti
# Processing City 519 | houma
# Processing City 520 | hambantota
# Processing City 521 | port augusta
# Processing City 522 | santa marta de tormes
# Processing City 523 | praxedis guerrero
# Processing City 524 | huntsville
# Processing City 525 | tekeli
# Processing City 526 | trairi
# Processing City 527 | saint-francois
# Processing City 528 | churumuco
# City not found. Skipping...
# Processing City 529 | tilichiki
# Processing City 530 | paulo afonso
# Processing City 531 | palana
# Processing City 532 | luau
# Processing City 533 | sao joaquim
# Processing City 534 | rancho palos verdes
# Processing City 535 | jambi
# Processing City 536 | inverell
# Processing City 537 | kaitangata
# Processing City 538 | anloga
# Processing City 539 | kushtagi
# Processing City 540 | kirovskiy
# Processing City 541 | bolitoc
# Processing City 542 | nadym
# Processing City 543 | phonhong
# Processing City 544 | cameta
# Processing City 545 | helena
# Processing City 546 | sao francisco
# Processing City 547 | puerto suarez
# Processing City 548 | agirish
# Processing City 549 | tankhoy
# Processing City 550 | dandong
# Processing City 551 | oktyabrskiy
# Processing City 552 | kushima
# Processing City 553 | kenora
# Processing City 554 | derzhavinsk
# Processing City 555 | port blair
# Processing City 556 | yuanping
# Processing City 557 | samalaeulu
# City not found. Skipping...
# Processing City 558 | broome
# Processing City 559 | arona
# Processing City 560 | asau
# Processing City 561 | ust-bolsheretsk
# City not found. Skipping...
# Processing City 562 | nakhon thai
# Processing City 563 | sistranda
# Processing City 564 | lasa
# Processing City 565 | ternate
# Processing City 566 | gangotri
# City not found. Skipping...
# Processing City 567 | aleppo
# Processing City 568 | jumla
# Processing City 569 | baykit
# Processing City 570 | kavaratti
# Processing City 571 | daru
# Processing City 572 | zhezkazgan
# Processing City 573 | diffa
# Processing City 574 | lorengau
# Processing City 575 | nawabganj
# Processing City 576 | bonnyville
# Processing City 577 | linhares
# Processing City 578 | ordynskoye
# Processing City 579 | kamina
# Processing City 580 | porto santo
# Processing City 581 | linqiong
# Processing City 582 | okha
# Processing City 583 | yar-sale
# Processing City 584 | omboue
# Processing City 585 | springdale
# Processing City 586 | bethanien
# Processing City 587 | guanica
# Processing City 588 | fairbanks
# Processing City 589 | lata
# Processing City 590 | bilibino
# Processing City 591 | imbituba
# Processing City 592 | oranjestad
# Processing City 593 | xinyang
# Processing City 594 | andenes
# Processing City 595 | sumbe
# Processing City 596 | cancun
# Processing City 597 | herat
# Processing City 598 | tortoli
# Processing City 599 | huarmey
# Processing City 600 | almeirim
# Processing City 601 | santa fe
# Processing City 602 | walvis bay
# Processing City 603 | bathurst
# Processing City 604 | luganville
# Processing City 605 | szczecinek

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_df.to_csv("Outputs/Weather-data.csv",index=False)
city_weather_df
# Out:
#             City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0    port alfred -33.59   26.89       68       85         25          3
# 1          rocha -34.48  -54.33    67.93       43          0       5.95
# 2        mataura -46.19  168.86       55       97        100          3
# 3      jamestown  42.10  -79.24       30       79         90       3.56
# 4         vieste  41.88   16.18       41       93          5       1.12
# ..           ...    ...     ...      ...      ...        ...        ...
# 552     santa fe -31.63  -60.70    87.01       20          0       1.12
# 553   walvis bay -22.96   14.51       63       77         95      11.41
# 554     bathurst -33.42  149.58       64       70         93       1.01
# 555   luganville -15.53  167.17     84.2       79         75       3.36
# 556   szczecinek  53.71   16.70    28.99       94         75       5.84
#
#     Country        Date
# 0        ZA  1609453377
# 1        UY  1609453379
# 2        NZ  1609453380
# 3        US  1609453381
# 4        IT  1609453382
# ..      ...         ...
# 552      AR  1609454085
# 553      NA  1609454002
# 554      AU  1609453851
# 555      VU  1609454089
# 556      PL  1609454090
#
# [557 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_weather_df[['Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Date']].astype(float).describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean    19.396050   16.115350   49.341041   75.299820   56.294434    8.080557
# std     33.406892   90.721131   32.140967   18.487646   38.908991    5.929160
# min    -54.800000 -175.200000  -43.600000   16.000000    0.000000    0.540000
# 25%     -8.840000  -60.630000   31.260000   68.000000   20.000000    3.360000
# 50%     21.970000   19.230000   60.010000   79.000000   74.000000    6.040000
# 75%     48.650000   96.130000   76.930000   88.000000   95.000000   11.410000
# max     78.220000  178.420000   91.400000  100.000000  100.000000   34.450000
#
#                Date
# count  5.570000e+02
# mean   1.609454e+09
# std    2.353510e+02
# min    1.609453e+09
# 25%    1.609454e+09
# 50%    1.609454e+09
# 75%    1.609454e+09
# max    1.609454e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp_df = city_weather_df[['Lat','Max Temp']]
lat_temp_df

plt.rcParams["figure.figsize"] = (12, 6)
lat_temp_df.plot.scatter("Lat", "Max Temp", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="Lattitude vs Max Temperature (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature (F)")
plt.savefig('Outputs/Scatter-Lat vs Temperature.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humidity_df = city_weather_df[['Lat','Humidity']]

plt.rcParams["figure.figsize"] = (12, 6)
lat_humidity_df.plot.scatter("Lat", "Humidity", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="Lattitude vs Humidity (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")
plt.savefig('Outputs/Scatter-Lat vs Humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloudiness_df = city_weather_df[['Lat','Cloudiness']]

plt.rcParams["figure.figsize"] = (12, 6)
lat_cloudiness_df.plot.scatter("Lat", "Cloudiness", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="Lattitude vs Cloudiness (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (%)")
plt.savefig('Outputs/Scatter-Lat vs Cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_Wind_df = city_weather_df[['Lat','Wind Speed']]

plt.rcParams["figure.figsize"] = (12, 6)
lat_Wind_df.plot.scatter("Lat", "Wind Speed", marker="o", edgecolors="black", s=75,
                         alpha=0.75, title="Lattitude vs Wind Speed (12/25/2020)")
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig('Outputs/Scatter-Lat vs WindSpeed.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
import scipy.stats as st
northern_df = city_weather_df.loc[city_weather_df['Lat']>=0]

x = northern_df['Lat'].astype(float)
y = northern_df['Max Temp'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Max Temp", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Max Temp", 
                         label="Temperatures")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(0,0),fontsize=20,color="red")
plt.ylabel('Max Temperature (F) ')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Northern-Lat vs Temp.png')
# Out:
# The r-value is: -0.8297033901911672

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_df = city_weather_df.loc[city_weather_df['Lat']<0]

x = southern_df['Lat'].astype(float)
y = southern_df['Max Temp'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Max Temp", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Max Temp", 
                         label="Temperatures")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-20,52),fontsize=20,color="red")
plt.ylabel('Max Temperature (F) ')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Southern-Lat vs Temp.png')
# Out:
# The r-value is: 0.46179290182782484

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Humidity'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Humidity", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Humidity(%)", 
                         label="Humidity(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(40,15),fontsize=20,color="red")
plt.ylabel('Humidity (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Northern-Lat vs Humidity.png')
# Out:
# The r-value is: 0.3784008064732654

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Humidity'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Humidity", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Humidity(%)", 
                         label="Humidity(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-20,15),fontsize=20,color="red")
plt.ylabel('Humidity (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Southern-Lat vs Humidity.png')
# Out:
# The r-value is: 0.29575427681462474

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Cloudiness'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Cloudiness", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Cloudiness (%)", 
                         label="Cloudiness(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(60,15),fontsize=20,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Northern-Lat vs Cloudiness.png')
# Out:
# The r-value is: 0.16730484018633504

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Cloudiness'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Cloudiness", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Cloudiness (%)", 
                         label="Cloudiness(%)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-55,10),fontsize=20,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Southern-Lat vs Cloudiness.png')
# Out:
# The r-value is: 0.3448083072625385

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_df['Lat']
y = northern_df['Wind Speed'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
northern_df.plot.scatter("Lat", "Wind Speed", color="green", s=75,
                         alpha=0.75, title="Northern Hemisphere - Linear Regression of Latitude vs Wind Speed (mph)", 
                         label="Wind Speed (mph)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(0,40),fontsize=20,color="red")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Northern-Lat vs Windspeed.png')
# Out:
# The r-value is: -0.007912334149320122

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_df['Lat']
y = southern_df['Wind Speed'].astype(float)

correlation = st.pearsonr(x,y)
# correlation = round(correlation[0],3)
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
y_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.rcParams["figure.figsize"] = (12, 6)
southern_df.plot.scatter("Lat", "Wind Speed", color="green", s=75,
                         alpha=0.75, title="Southern Hemisphere - Linear Regression of Latitude vs Wind Speed (mph)", 
                         label="Wind Speed (mph)")
plt.plot(x,y_values,"r-",label='Linear Regression')
plt.annotate(line_eq,(-38,22),fontsize=20,color="red")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Lattitude')
plt.legend()
plt.grid()
plt.savefig('Outputs/Southern-Lat vs Windspeed.png')
# Out:
# The r-value is: -0.1309385364389041
